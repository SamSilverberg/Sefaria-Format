# %% [markdown]
# ## Next:
# 1. Topic modeling per speaker?
# 2. Match names to generations

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string
from Linked_List import Linked_List

'''COLOR CODES'''##############################################################################################
def pink(st): 
    output = f"\u001b[48;5;219m{st}\u001b[0m"
    return str(output)
def pinkbright(st): 
    output = f"\u001b[48;5;225m{st}\u001b[0m"
    return str(output)
def violet(st): 
    output = f"\u001b[48;5;147m{st}\u001b[0m"
    return str(output)
def violetbright(st): 
    output = f"\u001b[48;5;189m{st}\u001b[0m"
    return str(output)
def blue(st): 
    output = f"\u001b[48;5;75m{st}\u001b[0m"
    return str(output)
def bluebright(st): 
    output = f"\u001b[48;5;87m{st}\u001b[0m"
    return str(output)
def turquoise(st): 
    output = f"\u001b[48;5;80m{st}\u001b[0m"
    return str(output)
def turquoisebright(st): 
    output = f"\u001b[48;5;122m{st}\u001b[0m"
    return str(output)
def green(st): 
    output = f"\u001b[48;5;78m{st}\u001b[0m"
    return str(output)
def greenbright(st): 
    output = f"\u001b[48;5;120m{st}\u001b[0m"
    return str(output)
def coral(st): 
    output = f"\u001b[48;5;216m{st}\u001b[0m"
    return str(output)
def coralbright(st): 
    output = f"\u001b[48;5;223m{st}\u001b[0m"
    return str(output)
def orange(st): 
    output = f"\u001b[48;5;214m{st}\u001b[0m"
    return str(output)
def yellow(st): 
    output = f"\u001b[48;5;220m{st}\u001b[0m"
    return str(output)
def yellowbright(st): 
    output = f"\u001b[48;5;226m{st}\u001b[0m"
    return str(output)
def bold(st):
    output = f"\033[1m{st}\u001b[0m"
    return str(output)


'''MAKE THE DAF'''##############################################################################################

daf = input('Enter the daf number and side you want to access (ex: 2b): ')

if daf[1] == 'a':
    stop = 'Daf '+daf[0]+'b'
else:
    dafnext = (int(daf[0])+1)
    stop = 'Daf '+str(dafnext)+'a'

with open(f"Berakhot.txt", encoding="utf8") as b:
    b = b.read()
    daffull = re.search(f'{daf}(.*){stop}', b, re.DOTALL)
    daffull = daffull.group(0) #return right clip
    daffull = daffull[0:-7] #cut off second daf and newline



'''CLEAN AND SPLIT INTO SENTENCES'''###############################################################################
d = daffull.split("\n")  #split at newlines, remove them

formatted = ''
for i in d:
    formatted += i.rstrip().lstrip() #string

readable = re.split('([.!?](?!\”|[e])|(?<=\”.)\s(?![(]))', formatted) #split string at punctuation
    
k = 0
for i in range(len(readable)): #merge punctuation back
    if k < (len(readable)-1):
        readable[k] = readable[k]+readable[k+1]
    elif k == len(readable):
        break
    k += 2

k = 1
for i in range(len(readable)): #delete punctuation only pieces
    if k < (len(readable)-1):
        del readable[k]
    elif k == len(readable):
        break
    k += 1

final1 = []
for i in readable:
    final1.append(i.lstrip()) 

final = []
for i in final1:
    clean = re.sub("\s+"," ", i)
    clean = re.sub("\s+[)]",")", clean)
    clean = re.sub("[(]+\s+","(", clean)
    clean = re.sub("\s+[]]","]", clean)
    clean = re.sub("[[]+\s+","[", clean)
    clean = re.sub("\s+[.]",".", clean)
    clean = re.sub("\s+[,]",",", clean)
    clean = re.sub("\s+[?]","?", clean)
    clean = re.sub("\s+[:]",":", clean)
    clean = re.sub("\"(?=\w)","” ", clean)
    final.append(clean+'\n')
    
'''TOPIC EXTRACTION WHOLE'''##########################################################################################               

clean = ' '.join(final)
clean = re.sub("\n"," ", clean)
clean = re.sub("[^-9A-Za-z ]"," ", clean)
clean = re.sub("\s+"," ", clean)
clean = "".join([i.lower() for i in clean if i not in string.punctuation])
words = re.split('\s', clean)
stop_words = set(stopwords.words('english')) 
words_new = [w for w in words if not w in stop_words]
words = ' '.join(words)
tokens = word_tokenize(words)
pos = nltk.pos_tag(tokens)
nouns = []
for i in pos:
    if i[1] == 'NN':
        nouns.append(i[0])

clean_nouns = []
for i in nouns:
    if len(i) > 3:
        clean_nouns.append(i)
counts = dict() #occurence counts
for word in clean_nouns:
    if word in counts:
        counts[word] += 1
    else:
        counts[word] = 1

biggestcount = 0
for key in counts.keys():
    if counts[key] > biggestcount:
        biggestcount = counts[key]
        word = key
if word != 'rabbi' and word != 'rabbis' and word != 'gemara':
    print(word,':',biggestcount)

biggestcount2 = 0
for key in counts.keys():
    if counts[key] > biggestcount2 and counts[key] < biggestcount:
        biggestcount2 = counts[key]
        word2 = key
if word2 != 'rabbi' and word2 != 'rabbis' and word2 != 'gemara':
    print(word2,':',biggestcount2)

biggestcount3 = 0
for key in counts.keys():
    if counts[key] > biggestcount3 and counts[key] < biggestcount2:
        biggestcount3 = counts[key]
        word3 = key
if word3 != 'rabbi' and word3 != 'rabbis' and word3 != 'gemara':
    print(word3,':',biggestcount3)

biggestcount4 = 0
for key in counts.keys():
    if counts[key] > biggestcount4 and counts[key] < biggestcount3:
        biggestcount4 = counts[key]
        word4 = key
if word4 != 'rabbi' and word4 != 'rabbis' and word4 != 'gemara':
    print(word4,':',biggestcount4)



'''TAG DIFFERENT SPEAKERS'''##########################################################################################
speakers = Linked_List()
colors = [blue, None, turquoise, None, green, None, yellow, None, orange, None, coral, None, pink, None, violet, None, bluebright, None, turquoisebright, None, greenbright, None, yellowbright, None, coralbright, None, pinkbright, None, violetbright]
k = 0
for i in final:
    if re.search(r'([R]+[a|.]+\w+\s+)', i): 
        two = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|\bRabbi\b\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|\bRabbi\b\s+\w+)(.*)', i)
        one = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|[R]+[a|.]+\w+s\w+)(.*)', i)
        four = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|^[R]+[a|.]+\w+s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
        three = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|^[R]+[a|.]+\w+s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
        four_beginning = re.search(r'(^[R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|^[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
        three_beginning = re.search(r'(^[R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|^[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
        if four_beginning: 
            if four_beginning.group(1) not in str(speakers):
                speakers.append_element(four_beginning.group(1))
            if four_beginning.group(3) not in str(speakers):
                speakers.append_element(four_beginning.group(3))
            if four_beginning.group(5) not in str(speakers):
                speakers.append_element(four_beginning.group(5))
            if four_beginning.group(7) not in str(speakers):
                speakers.append_element(four_beginning.group(7))
        if four: 
            if four.group(2) not in str(speakers):
                speakers.append_element(four.group(2))
            if four.group(4) not in str(speakers):
                speakers.append_element(four.group(4))
            if four.group(6) not in str(speakers):
                speakers.append_element(four.group(6))
            if four.group(8) not in str(speakers):
                speakers.append_element(four.group(8))
        if three_beginning:
            if three_beginning.group(1) not in str(speakers):
                speakers.append_element(three_beginning.group(1))
            if three_beginning.group(3) not in str(speakers):
                speakers.append_element(three_beginning.group(3))
            if three_beginning.group(5) not in str(speakers):
                speakers.append_element(three_beginning.group(5))
        if three:
            if three.group(2) not in str(speakers):
                speakers.append_element(three.group(2))
            if three.group(4) not in str(speakers):
                speakers.append_element(three.group(4))
            if three.group(6) not in str(speakers):
                speakers.append_element(three.group(6))
        if two:
            if two.group(2) not in str(speakers):
                speakers.append_element(two.group(2))
            if two.group(4) not in str(speakers):
                speakers.append_element(two.group(4))
        elif one:
            if one.group(2) not in str(speakers):
                speakers.append_element(one.group(2))
# print('\n'+bold('SPEAKERS'))
# for i in speakers:
#     print(i)
                
'''ASSIGN COLORS FOR SPEAKERS'''##########################################################################################      
# si = 0
# for index,val in enumerate(colors):
#     if index%2==1: 
#         colors[index] = speakers[si]
#         si +=1
#     if si == len(speakers):
#         break
        
# for speakerindex, speakerval in enumerate(speakers):
#     for colorindex, colorval in enumerate(colors):
#         if speakerval == colorval:
#             speakers[speakerindex] = colors[colorindex-1](speakerval)

print('\n=========================================================================================\n')

    
'''APPLY COLORS & BOLD TO FULL TEXT'''##########################################################################################
k = 0
layout = Linked_List()
for i in final:
#     if re.search(r'(.*)(\bGemara\b)(.*)', i):
    answer = re.search(r'(.*)(\bGemara\b\s\bexplains\b|\bGemara\b\s\bnotes\b|\bGemara\b\s\brelates\b|\bGemara\b\s\banswers\b|\bGemara\b\s\brecords\b)(.*)([.])', i)
    question = re.search(r'(.*)([?])(.*)', i)
    if answer:
        prefix = answer.group(1)
        gemara = answer.group(2)
        suffix = answer.group(3)
        punct = answer.group(4)
        a = re.match(r'.*(?![?.!:])', suffix)
        final[k] = turquoise(prefix+gemara+suffix+'\n\n')
    if question:
        prefix = question.group(1)
        gemara = question.group(2)
        suffix = question.group(3)
        q = re.match(r'.*(?![?])', suffix)
        final[k] = coral(prefix+gemara+" "+suffix+'\n\n')
    two = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|\bRabbi\b\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|\bRabbi\b\s+\w+)(.*)', i)
    one = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|[R]+[a|.]+\w+s\w+)(.*)', i)
    four = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|^[R]+[a|.]+\w+s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
    three = re.search(r'(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+|^[R]+[a|.]+\w+s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
    four_beginning = re.search(r'(^[R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|^[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
    three_beginning = re.search(r'(^[R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|^[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)([R]+[a|.]+\w+\s+\w+\s?(?=\bbar\b|\bben\b)\w+\s+\w+|[R]+[a|.]+\w+\s+\w+)(.*)', i)
    if four:
        prefix = four.group(1)
        name1 = four.group(2)
        between1 = four.group(3)
        name2 = four.group(4)
        between2 = four.group(5)
        name3 = four.group(6)
        between3 = four.group(7)
        name4 = four.group(8)
        suffix = four.group(9)
        newline = prefix+bold(name1)+between1+bold(name2)+between2+bold(name3)+between3+bold(name4)+suffix+'\n'
        final[k] = newline
    if four_beginning:
        name1 = four_beginning.group(1)
        between1 = four_beginning.group(2)
        name2 = four_beginning.group(3)
        between2 = four_beginning.group(4)
        name3 = four_beginning.group(5)
        between3 = four_beginning.group(6)
        name4 = four_beginning.group(7)
        suffix = four_beginning.group(8)
        newline = bold(name1)+between1+bold(name2)+between2+bold(name3)+between3+bold(name4)+suffix+'\n'
        final[k] = newline
    elif three:
        prefix = three.group(1)
        name1 = three.group(2)
        between1 = three.group(3)
        name2 = three.group(4)
        between2 = three.group(5)
        name3 = three.group(6)
        suffix = three.group(7)
        newline = prefix+bold(name1)+between1+bold(name2)+between2+bold(name3)+suffix+'\n'
        final[k] = newline
    elif three_beginning:
        name1 = three_beginning.group(1)
        between1 = three_beginning.group(2)
        name2 = three_beginning.group(3)
        between2 = three_beginning.group(4)
        name3 = three_beginning.group(5)
        suffix = three_beginning.group(6)
        newline = bold(name1)+between1+bold(name2)+between2+bold(name3)+suffix+'\n'
        final[k] = newline
    elif two:
        prefix = two.group(1)
        name1 = two.group(2)
        between = two.group(3)
        name2 = two.group(4)
        suffix = two.group(5)
        newline = prefix+bold(name1)+between+bold(name2)+suffix+'\n'
        final[k] = newline
    elif one:
        prefix = one.group(1)
        name = one.group(2)
        suffix = one.group(3)
        newline = prefix+bold(name)+suffix+'\n'
        final[k] = newline
    layout.append_element(final[k])
    k += 1
    
'''GENERATIONS'''#######################################################################################   

# amoraim1 = 
# amoraim2 = 
# amoraim3 = 
# amoraim4 =
# amoraim5 =
# print(layout)
for i in layout:
    print(i)
# Out:
# Enter the daf number and side you want to access (ex: 2b): 2b
# time : 48
# person : 20
# evening : 14
# night : 13
#
# ...
#
# 2bPerhaps the expression: “And the sun sets and it is purified” refers to the very beginning of sunset, the setting of the sun’s light.
#
# According to that explanation, what does the expression and it is purified mean?
#
#
# It means that the person will become purified.
#
# After immersing, he will wait until the beginning of sunset, and only then will he be able to eat of his teruma (Tosafot).
#
# Rabba bar Rav Sheila said: If so, that: And it is purified, means that the priest goes and purifies himself, then let the verse say unambiguously: And he will become purified.
#
# Since the Torah does not employ that language, the conclusion is: What is the meaning of the expression: And it is purified?
#
#
# It means the day is pure, no residue of day remains, as people say colloquially: The sun has set and the day is purified.
#
# ...
